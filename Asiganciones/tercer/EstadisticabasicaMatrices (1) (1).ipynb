# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h1 class="alert-heading">Estadística Básica de Datos, Tercer Cuaderno</h1>
#   <h3 class="alert-heading">Estud. Laura Cristina Jiménez Ruiz, lauracris97@hotmail.com</h3>
#   <h3 class="alert-heading">Prof. Enrique Mejía Ospino, emejia@uis.edu.co</h3>
#   <h4 class="alert-heading">Escuela de Química</h4>
#   <h5 class="alert-heading">Universidad Industrial de Santander</h5>
#   <p>
#   </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import glob
all_data3 = pd.DataFrame()
#nombres=['MF']
for f in glob.glob("C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/FT*.csv"):
    df = pd.read_csv(f, header=None, delimiter=',' )
    all_data3 = pd.concat([all_data3, df], axis=1)
    #nombres.append(f[6:12])
    print(f)
#Data = all_data3[1]
# Out:
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos\FTIR_C1.CSV
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos\FTIR_C2.CSV
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos\FTIR_C3.CSV
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos\FTIR_C4.CSV

# %%
all_data3
# Out:
#               0          1          0          1          0          1  \
# 0      399.6813    0.00000   399.6813    0.00000   399.6813    0.00000
# 1      400.1635   97.31300   400.1635   95.65128   400.1635   96.48417
# 2      400.6456   97.34521   400.6456   95.56998   400.6456   96.52913
# 3      401.1277   97.41083   401.1277   95.54085   401.1277   96.57450
# 4      401.6098   97.47359   401.6098   95.55093   401.6098   96.61844
# ...         ...        ...        ...        ...        ...        ...
# 7464  3998.2590  100.44860  3998.2590  100.32160  3998.2590  100.25590
# 7465  3998.7410  100.44990  3998.7410  100.32090  3998.7410  100.25810
# 7466  3999.2240  100.45110  3999.2240  100.32000  3999.2240  100.25980
# 7467  3999.7060  100.45190  3999.7060  100.31940  3999.7060  100.26060
# 7468  4000.1880  100.45210  4000.1880  100.31920  4000.1880  100.26050
#
#               0         1
# 0      399.6813   0.00000
# 1      400.1635  98.43222
# 2      400.6456  98.46598
# ...

# %%
len(all_data3.columns)
# Out:
# 8

# %%
data=all_data3.drop(all_data3.index[[0]]) # Eliminamos el primer la primera fila
ys=data[1]
data.columns=range(data.shape[1])
xs=data[[0]]
ys.columns=range(ys.shape[1])
#all_data3.drop(all_data3[1:0])
data
# Out:
#               0          1          2          3          4          5  \
# 1      400.1635   97.31300   400.1635   95.65128   400.1635   96.48417
# 2      400.6456   97.34521   400.6456   95.56998   400.6456   96.52913
# 3      401.1277   97.41083   401.1277   95.54085   401.1277   96.57450
# 4      401.6098   97.47359   401.6098   95.55093   401.6098   96.61844
# 5      402.0919   97.49519   402.0919   95.58916   402.0919   96.65531
# ...         ...        ...        ...        ...        ...        ...
# 7464  3998.2590  100.44860  3998.2590  100.32160  3998.2590  100.25590
# 7465  3998.7410  100.44990  3998.7410  100.32090  3998.7410  100.25810
# 7466  3999.2240  100.45110  3999.2240  100.32000  3999.2240  100.25980
# 7467  3999.7060  100.45190  3999.7060  100.31940  3999.7060  100.26060
# 7468  4000.1880  100.45210  4000.1880  100.31920  4000.1880  100.26050
#
#               6         7
# 1      400.1635  98.43222
# 2      400.6456  98.46598
# 3      401.1277  98.40218
# ...

# %%
ys=np.array(ys)
xs=np.array(xs)
fig, esp= plt.subplots(1,2, figsize=(20, 6))
plt.rcParams["font.family"] = 'Times New Roman'
esp[0].plot(xs, ys)
esp[0].set_xlim(400, 4000)
esp[0].set_title("FTIR:Petróleo, todas las muestras")
esp[0].set_xlabel("número de onda")
esp[0].set_ylabel("Absorbancia")
esp[1].plot(xs, ys[:,1])
esp[1].set_xlim(400, 4000)
esp[1].set_title("FTIR:Petróleo, muestra 1")
esp[1].set_xlabel("número de onda");
#esp2.set_ylabel("Absorbancia")
#plt.subplots_adjust(left=1, wspace=0.3, hspace=5, bottom=0.1, top=0.9, right=3)

# %%
datosr = np.random.randn(1000)
#datosr = np.random.randint(10, size=10) # datos n00rmalmente distribuidos
#datosr

# %%
plt.plot(datosr)

# %%
datosr.mean()
# Out:
# 0.026549032740541142

# %%
np.mean(datosr)
# Out:
# 0.026549032740541142

# %%
ys=np.array(ys)
xs=np.array(xs)
fig, esp= plt.subplots(1,2, figsize=(20, 6))
plt.rcParams["font.family"] = 'Times New Roman'
esp[0].plot(xs, ys)
esp[0].set_xlim(400, 4000)
esp[0].set_title("FTIR:Petróleo, todas las muestras")
esp[0].set_xlabel("número de onda")
esp[0].set_ylabel("Absorbancia")
esp[1].plot(xs, ys.mean(axis=1), 'r', label='espectro promedio')
esp[1].set_xlim(400, 4000)
esp[1].set_title("FTIR:Petróleo, muestra 1")
esp[1].set_xlabel("número de onda");
esp[1].legend(loc='best', fontsize=12)
#plt.subplots_adjust(left=1, wspace=0.3, hspace=5, bottom=0.1, top=0.9, right=3)

# %%
datosr, np.median(datosr)
# Out:
# (array([-9.15835152e-01, -8.29431401e-01, -3.96249617e-02, -1.65855166e+00,
#         -6.51408547e-01, -8.33326930e-01, -7.39432792e-01, -2.22702111e+00,
#         -2.74394742e-02,  8.54429109e-01, -8.61069370e-01, -9.46742822e-01,
#         -1.24242230e-01,  1.02830412e-01,  1.41449144e+00,  1.81167008e+00,
#          1.09795417e-01,  1.68524314e+00,  6.24189826e-01, -3.48420350e-01,
#         -2.30174532e+00, -7.33472629e-01,  1.05144023e+00, -3.90731708e-01,
#         -5.19463854e-01, -5.24402962e-01, -9.06900526e-01,  2.05463499e+00,
#          2.87115277e-02,  2.07144293e+00,  4.83047933e-02, -8.17743572e-01,
#          2.55099808e+00, -7.98824128e-01, -1.18488579e-01,  1.99406737e+00,
#          1.55308381e+00,  1.61444462e+00, -2.04865247e-01, -1.20788404e-01,
#         -5.80725774e-01,  2.57351685e-01, -2.52748987e-01,  2.55412773e-01,
#          7.50351232e-02, -6.81982936e-01, -3.38356971e-01,  3.07910065e-01,
# ...

# %%
ys=np.array(ys)
xs=np.array(xs)
fig, esp= plt.subplots(1,2, figsize=(20, 6))
plt.rcParams["font.family"] = 'Times New Roman'
esp[0].plot(xs, ys)
esp[0].set_xlim(400, 4000)
esp[0].set_title("FTIR:Petróleo, todas las muestras")
esp[0].set_xlabel("número de onda")
esp[0].set_ylabel("Absorbancia")
esp[1].plot(xs, np.median(ys, 1), 'b', label='espectro mediana')
esp[1].set_xlim(400, 4000)
esp[1].set_title("FTIR:Petróleo, muestra 1")
esp[1].set_xlabel("número de onda");
esp[1].legend(loc='best', fontsize=12)
#plt.subplots_adjust(left=1, wspace=0.3, hspace=5, bottom=0.1, top=0.9, right=3)

# %%
np.var(datosr)
# Out:
# 0.9461797374245584

# %%
ys=np.array(ys)
xs=np.array(xs)
fig, esp= plt.subplots(1,2, figsize=(20, 6))
plt.rcParams["font.family"] = 'Times New Roman'
esp[0].plot(xs, ys)
esp[0].set_xlim(400, 4000)
esp[0].set_title("FTIR:Petróleo, todas las muestras")
esp[0].set_xlabel("número de onda")
esp[0].set_ylabel("Absorbancia")
esp[1].plot(xs, np.var(ys, 1), 'g', label='espectro mediana')
esp[1].set_xlim(400, 4000)
esp[1].set_title("FTIR:Petróleo, muestra 1")
esp[1].set_xlabel("número de onda");
esp[1].legend(loc='best', fontsize=12)
#plt.subplots_adjust(left=1, wspace=0.3, hspace=5, bottom=0.1, top=0.9, right=3)

# %%
np.std(datosr)
# Out:
# 0.9727177069553933

# %%
ys=np.array(ys)
xs=np.array(xs)
fig, esp= plt.subplots(1,2, figsize=(20, 6))
plt.rcParams["font.family"] = 'Times New Roman'
esp[0].plot(xs, ys)
esp[0].set_xlim(400, 4000)
esp[0].set_title("FTIR:Petróleo, todas las muestras")
esp[0].set_xlabel("número de onda")
esp[0].set_ylabel("Absorbancia")
esp[1].plot(xs, np.std(ys, 1), 'c', label='espectro mediana')
esp[1].set_xlim(400, 4000)
esp[1].set_title("FTIR:Petróleo, muestra 1")
esp[1].set_xlabel("número de onda");
esp[1].legend(loc='best', fontsize=12)
#plt.subplots_adjust(left=1, wspace=0.3, hspace=5, bottom=0.1, top=0.9, right=3)

# %%
np.corrcoef(ys)
# Out:
# array([[ 1.        ,  0.99938587,  0.99681229, ..., -0.80261619,
#         -0.80244244, -0.80239497],
#        [ 0.99938587,  1.        ,  0.99880138, ..., -0.78943524,
#         -0.78925035, -0.78920178],
#        [ 0.99681229,  0.99880138,  1.        , ..., -0.75932159,
#         -0.75912314, -0.7590718 ],
#        ...,
#        [-0.80261619, -0.78943524, -0.75932159, ...,  1.        ,
#          0.99999993,  0.99999991],
#        [-0.80244244, -0.78925035, -0.75912314, ...,  0.99999993,
#          1.        ,  1.        ],
#        [-0.80239497, -0.78920178, -0.7590718 , ...,  0.99999991,
#          1.        ,  1.        ]])

# %%
datosr= np.random.randint(10, size=10)
datosr
# Out:
# array([7, 9, 6, 4, 7, 5, 1, 5, 2, 6])

# %%
datosr1 = np.random.randint(10, size=10)
datosr1
# Out:
# array([8, 9, 4, 6, 3, 4, 3, 7, 1, 5])

# %%
np.corrcoef(datosr, datosr1)
# Out:
# array([[1.        , 0.66970515],
#        [0.66970515, 1.        ]])

# %% [markdown]
# <font color=blue, size=6>**Clase del martes.**

# %%
datafile="C:/Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Isoc-Chrom.xlsx"#este archivo contiene tres hojas de calculo 
data = pd.read_excel(datafile)
data
# Out:
#    Mol-Isoctano  Area-Pico
# 0         0.352       1.09
# 1         0.803       1.78
# 2         1.080       2.60
# 3         1.380       3.03
# 4         1.750       4.01

# %%
# Librería numpy permite obtener la pendiente y el corte de un ajuste lineal entre dos serie datos
import numpy as np
x=data['Mol-Isoctano']#dato de la concentración #Mol-Isoctano
y=data['Area-Pico'] 
# Ajuste a una recta (polinomio de grado 1)
p = np.polyfit(x, y, 1)
# No es posible obtener métricas estadísticas con el coeficiente de regresión
print(p)
# y(x)=p0x+p1=1.00000009e+00x-4.29084910e-05, muestra la pendiente y el corte
# Out:
# [2.09250651 0.25674051]

# %% [markdown]
# <font color=green, size=6> **Gráfica regresión lineal.**

# %%
c =np.arange(0,2,0.01)
plt.scatter(x,y)
plt.plot(c, 2.09*c+0.26)

# %% [markdown]
# <font color=pink, size=6> **Curvas de Calibración.**

# %% [markdown]
# ### <font color=red> Curva del Calibración Na y Área bajo la curva.

# %%
import glob
cvc = pd.DataFrame()
#nombres=['MF']
for f in glob.glob("C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Na/CURVA2/*C2.asc"):
    df = pd.read_csv(f, header=None, delimiter='\t' )
    cvc = pd.concat([cvc, df], axis=1)
    print(f)
data=cvc.drop(cvc.index[[0]]) # Eliminamos el primer la primera fila
ysNa=data[1]
data.columns=range(data.shape[1])
xsNa=data[[0]]
ysNa.columns=range(ysNa.shape[1])
# Out:
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Na/CURVA2\1145 C2.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Na/CURVA2\11450 C2.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Na/CURVA2\18320 C2.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Na/CURVA2\25000 C2.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Na/CURVA2\35000 C2.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Na/CURVA2\45000 C2.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Na/CURVA2\6870 C2.asc

# %%
ysNa=np.array(ysNa)
xsNa=np.array(xsNa)
fig, esp= plt.subplots(figsize=(12, 6))
plt.rcParams["font.family"] = 'Times New Roman'
esp.plot(xsNa, ysNa[:,0])
esp.set_xlim(np.min(xsNa)+10, np.max(xsNa)-10)
esp.set_title("LIBS Spectra Na")
esp.set_xlabel("Wavelenght (nm)")
esp.set_ylabel("Intensity (arb. units)");

# %%
plt.plot(ysNa[450:550]-np.min(ysNa[0:,0]));

# %%
A1=(ysNa[450:550]-np.min(ysNa[0:,0])).sum(axis=0)
C1=pd.DataFrame([1145, 11450, 18320, 25000, 35000, 45000, 6870])
A1=pd.DataFrame(A1)
D1=pd.concat([C1, A1], axis=1)
D1=D1.set_axis(['[ppm]', 'Int'], axis=1, inplace=False)
D1
# Out:
#    [ppm]     Int
# 0   1145  248644
# 1  11450  467919
# 2  18320  563554
# 3  25000  638372
# 4  35000  808007
# 5  45000  934683
# 6   6870  344571

# %%
from bokeh.io import output_notebook, show, output_file, export_png
from bokeh.plotting import figure, show
from bokeh.models import Segment, ColumnDataSource

output_notebook() # Ver la figura en el cuaderno

TOOLS="zoom_in,zoom_out,box_zoom,undo,redo,reset,save,box_select,poly_select,lasso_select,"

# Graficación
p = figure(title='FTIR', plot_width=600, plot_height=400, x_range=(np.min(xsNa), np.max(xsNa)),  x_axis_label='Wavenumber (cm-1)', y_axis_label='Intensity (arb. units)', toolbar_location="above", tools=TOOLS)
p.grid.grid_line_alpha=0.3
p.line(xsNa[:,0], ysNa[:,2], color='red', line_width=2, legend_label='PLA', alpha=0.9)
#p.line(ir2[:,0], ir2[:,1]-20, color='blue', line_width=2, legend_label='PLA-Grafeno', alpha=0.5)

#ax.plot(ir3[:,0], ir3[:,1]-40, 'b', label='FTIR-FC', lw=2)

p.legend.location = "bottom_right"
p.grid.visible = True
p.title.align = "center"
p.title.text_font_size = "20px"

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6756">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="aef7282f-acba-4c7e-a609-1f73635f9087" data-root-id="6757"></div>

# %% [markdown]
# ### <font color=red> Curva del Calibración Ca y Área bajo la curva.

# %%
cvc = pd.DataFrame()
#nombres=['MF']
for f2 in glob.glob("C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Ca/CURVA1/*C1.asc"):
    df = pd.read_csv(f2, header=None, delimiter='\t' )
    cvc = pd.concat([cvc, df], axis=1)
    print(f2)
dataCa=cvc.drop(cvc.index[[0]]) # Eliminamos el primer la primera fila
ysCa=dataCa[1]
dataCa.columns=range(dataCa.shape[1])
xsCa=dataCa[[0]]
ysCa.columns=range(ysCa.shape[1])
# Out:
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Ca/CURVA1\1122,2 c1.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Ca/CURVA1\14427,5 c1.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Ca/CURVA1\18836 c1.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Ca/CURVA1\4008 c1.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Ca/CURVA1\9217 c1.asc

# %%
ysCa=np.array(ysCa)
xsCa=np.array(xsCa)
fig, esp= plt.subplots(figsize=(12, 6))
plt.rcParams["font.family"] = 'Times New Roman'
esp.plot(xsCa, ysCa[:,1])
esp.set_xlim(np.min(xsCa)+10, np.max(xsCa)-10)
esp.set_title("LIBS Spectra Ca")
esp.set_xlabel("Wavelenght (nm)")
esp.set_ylabel("Intensity (arb. units)");

# %%
plt.plot(ysCa[330:400]-np.min(ysCa[0:,0]));

# %%
A1Ca=(ysCa[330:400]-np.min(ysCa[0:,0])).sum(axis=0)
C1Ca=pd.DataFrame([1122.2, 14427.5, 18836, 4008, 9217])
A1Ca=pd.DataFrame(A1Ca)
D1Ca=pd.concat([C1Ca, A1Ca], axis=1)
D1Ca=D1Ca.set_axis(['[ppm]', 'Int'], axis=1, inplace=False)
D1Ca
# Out:
#      [ppm]     Int
# 0   1122.2   97371
# 1  14427.5  288337
# 2  18836.0  385685
# 3   4008.0  134237
# 4   9217.0  199470

# %%
from bokeh.io import output_notebook, show, output_file, export_png
from bokeh.plotting import figure, show
from bokeh.models import Segment, ColumnDataSource

output_notebook() # Ver la figura en el cuaderno

TOOLS="zoom_in,zoom_out,box_zoom,undo,redo,reset,save,box_select,poly_select,lasso_select,"

# Graficación
p = figure(title='FTIR', plot_width=600, plot_height=400, x_range=(np.min(xsCa), np.max(xsCa)),  x_axis_label='Wavenumber (cm-1)', y_axis_label='Intensity (arb. units)', toolbar_location="above", tools=TOOLS)
p.grid.grid_line_alpha=0.3
p.line(xsCa[:,0], ysCa[:,2], color='red', line_width=2, legend_label='PLA', alpha=0.9)
#p.line(ir2[:,0], ir2[:,1]-20, color='blue', line_width=2, legend_label='PLA-Grafeno', alpha=0.5)

#ax.plot(ir3[:,0], ir3[:,1]-40, 'b', label='FTIR-FC', lw=2)

p.legend.location = "bottom_right"
p.grid.visible = True
p.title.align = "center"
p.title.text_font_size = "20px"

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7173">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="66b5c00e-478a-4e08-8598-d197842e8703" data-root-id="7174"></div>

# %% [markdown]
# ### <font color=red> Curva del Calibración K y Área bajo la curva.

# %%
cvc = pd.DataFrame()
#nombres=['MF']
for f3 in glob.glob("C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/K/CURVA2/*C2.asc"):
    df = pd.read_csv(f3, header=None, delimiter='\t' )
    cvc = pd.concat([cvc, df], axis=1)
    print(f3)
dataK=cvc.drop(cvc.index[[0]]) # Eliminamos el primer la primera fila
ysK=dataK[1]
dataK.columns=range(dataK.shape[1])
xsK=dataK[[0]]
ysK.columns=range(ysK.shape[1])
# Out:
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/K/CURVA2\13684,4 c2.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/K/CURVA2\3909.8  c2.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/K/CURVA2\7037,6 c2.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/K/CURVA2\977.4 c2.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/K/CURVA2\9779.5 c2.asc

# %%
ysK=np.array(ysK)
xsK=np.array(xsK)
fig, esp= plt.subplots(figsize=(12, 6))
plt.rcParams["font.family"] = 'Times New Roman'
esp.plot(xsK, ysK[:,0])
esp.set_xlim(np.min(xsK)+5, np.max(xsK)-5)
esp.set_title("LIBS Spectra K")
esp.set_xlabel("Wavelenght (nm)")
esp.set_ylabel("Intensity (arb. units)");

# %%
plt.plot(ysK[180:220]-np.min(ysK[0:,0]));

# %%
A1K=(ysK[180:220]-np.min(ysK[0:,0])).sum(axis=0)
C1K=pd.DataFrame([13684.4, 3909.8, 7037.6, 977.4, 9779.5])
A1K=pd.DataFrame(A1K)
D1K=pd.concat([C1K, A1K], axis=1)
D1K=D1K.set_axis(['[ppm]', 'Int'], axis=1, inplace=False)
D1K
# Out:
#      [ppm]     Int
# 0  13684.4  359378
# 1   3909.8  208551
# 2   7037.6  309200
# 3    977.4  204675
# 4   9779.5  335735

# %%
from bokeh.io import output_notebook, show, output_file, export_png
from bokeh.plotting import figure, show
from bokeh.models import Segment, ColumnDataSource

output_notebook() # Ver la figura en el cuaderno

TOOLS="zoom_in,zoom_out,box_zoom,undo,redo,reset,save,box_select,poly_select,lasso_select,"

# Graficación
p = figure(title='FTIR', plot_width=600, plot_height=400, x_range=(np.min(xsK), np.max(xsK)),  x_axis_label='Wavenumber (cm-1)', y_axis_label='Intensity (arb. units)', toolbar_location="above", tools=TOOLS)
p.grid.grid_line_alpha=0.3
p.line(xsK[:,0], ysK[:,2], color='red', line_width=2, legend_label='PLA', alpha=0.9)
#p.line(ir2[:,0], ir2[:,1]-20, color='blue', line_width=2, legend_label='PLA-Grafeno', alpha=0.5)

#ax.plot(ir3[:,0], ir3[:,1]-40, 'b', label='FTIR-FC', lw=2)

p.legend.location = "bottom_right"
p.grid.visible = True
p.title.align = "center"
p.title.text_font_size = "20px"

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7603">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d590fb2f-5654-478c-8c5d-7b560294b64b" data-root-id="7604"></div>

# %% [markdown]
# ### <font color=red> Curva del Calibración Mg y Área bajo la curva.

# %%
cvc = pd.DataFrame()
#nombres=['MF']
for f4 in glob.glob("C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Mg/CURVA 3/*C3.asc"):
    df = pd.read_csv(f4, header=None, delimiter='\t' )
    cvc = pd.concat([cvc, df], axis=1)
    print(f4)
dataMg=cvc.drop(cvc.index[[0]])
# Eliminamos el primer la primera fila
ysMg=dataMg[1]
dataMg.columns=range(dataMg.shape[1])
xsMg=dataMg[[0]]
ysMg.columns=range(ysMg.shape[1])
# Out:
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Mg/CURVA 3\1142 c3.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Mg/CURVA 3\14097 c3.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Mg/CURVA 3\2430 c3.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Mg/CURVA 3\5833 c3.asc
# C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Mg/CURVA 3\9772 c3.asc

# %%
ysMg=np.array(ysMg)
xsMg=np.array(xsMg)
fig, esp= plt.subplots(figsize=(12, 6))
plt.rcParams["font.family"] = 'Times New Roman'
esp.plot(xsMg, ysMg[:,0])
esp.set_xlim(np.min(xsMg)+14, np.max(xsMg)-14)
esp.set_title("LIBS Spectra Mg")
esp.set_xlabel("Wavelenght (nm)")
esp.set_ylabel("Intensity (arb. units)");

# %%
plt.plot(ysMg[490:510]-np.min(ysMg[0:,0]));

# %%
A1Mg=(ysMg[490:510]-np.min(ysMg[0:,0])).sum(axis=0)
C1Mg=pd.DataFrame([1142, 14097, 2430, 5833, 9772])
A1Mg=pd.DataFrame(A1Mg)
D1Mg=pd.concat([C1Mg, A1Mg], axis=1)
D1Mg=D1Mg.set_axis(['[ppm]', 'Int'], axis=1, inplace=False)
D1Mg
# Out:
#    [ppm]     Int
# 0   1142   63543
# 1  14097  169552
# 2   2430   70470
# 3   5833  105571
# 4   9772  131165

# %%
from bokeh.io import output_notebook, show, output_file, export_png
from bokeh.plotting import figure, show
from bokeh.models import Segment, ColumnDataSource

output_notebook() # Ver la figura en el cuaderno

TOOLS="zoom_in,zoom_out,box_zoom,undo,redo,reset,save,box_select,poly_select,lasso_select,"

# Graficación
p = figure(title='FTIR', plot_width=600, plot_height=400, x_range=(np.min(xsMg), np.max(xsMg)),  x_axis_label='Wavenumber (cm-1)', y_axis_label='Intensity (arb. units)', toolbar_location="above", tools=TOOLS)
p.grid.grid_line_alpha=0.3
p.line(xsMg[:,0], ysMg[:,2], color='red', line_width=2, legend_label='PLA', alpha=0.9)
#p.line(ir2[:,0], ir2[:,1]-20, color='blue', line_width=2, legend_label='PLA-Grafeno', alpha=0.5)

#ax.plot(ir3[:,0], ir3[:,1]-40, 'b', label='FTIR-FC', lw=2)

p.legend.location = "bottom_right"
p.grid.visible = True
p.title.align = "center"
p.title.text_font_size = "20px"

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8046">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="5a03ea8e-ef27-44e7-9e18-04b76cde0e75" data-root-id="8047"></div>

# %% [markdown]
# ### <font color=red> Gráficas de las Curvas de Calibración.

# %%
import sklearn.metrics as skm
from sklearn import linear_model
x=D1[['[ppm]']] 
y=D1[['Int']]
reg = linear_model.LinearRegression()
reg.fit(x, y)
y1_pred = reg.predict(x)
m=reg.coef_[0]
b=reg.intercept_[0]
mse=skm.mean_squared_error(y, y1_pred)
r2=skm.r2_score(y, y1_pred)
x= np.array(x)

# %%
fig, ax= plt.subplots()
ax.scatter(x, y, color='green', label='Original Data', edgecolors='black')
ax.plot(x, y1_pred, 'r', label='Fitted line')
ax.legend()
ax.set_title("Curva de Calibración Na")
ax.set_xlabel("Concentración (ppm)")
ax.set_ylabel("Intensidad (units arb.)")
ax.text(30000,0.4e6, r"$r^2 = "+str("{0:.3f}".format(r2Ca))+r"$", fontsize=12, color="black")
plt.show()
fig.savefig("2.pdf",bbox_inches='tight')

# %%
import sklearn.metrics as skm
from sklearn import linear_model
xCa=D1Ca[['[ppm]']] 
yCa=D1Ca[['Int']]
reg = linear_model.LinearRegression()
reg.fit(xCa, yCa)
y2_pred = reg.predict(xCa)
mCa=reg.coef_[0]
bCa=reg.intercept_[0]
mse=skm.mean_squared_error(yCa, y2_pred)
r2Ca=skm.r2_score(yCa, y2_pred)
xCa= np.array(xCa)

# %%
fig, ax= plt.subplots()
ax.scatter(xCa, yCa, color='green', label='Original Data', edgecolors='black')
ax.plot(xCa, y2_pred, 'r', label='Fitted line')
ax.legend()
ax.set_title("Curva de Calibración Ca")
ax.set_xlabel("Concentración (ppm)")
ax.set_ylabel("Intensidad (units arb.)")
ax.text(14000,0.9e5, r"$r^2 = "+str("{0:.3f}".format(r2Ca))+r"$", fontsize=12, color="black")
plt.show()
fig.savefig("2.pdf",bbox_inches='tight')

# %%
import sklearn.metrics as skm
from sklearn import linear_model
xK=D1K[['[ppm]']] 
yK=D1K[['Int']]
reg = linear_model.LinearRegression()
reg.fit(xK, yK)
y3_pred = reg.predict(xK)
mK=reg.coef_[0]
bK=reg.intercept_[0]
mse=skm.mean_squared_error(yK, y3_pred)
r2K=skm.r2_score(yK, y3_pred)
xK= np.array(xK)

# %%
fig, ax= plt.subplots()
ax.scatter(xK, yK, color='green', label='Datos originales', edgecolors='black')
ax.plot(xK, y3_pred, 'r', label='Ajuste')
ax.legend()
ax.set_title("Curva de Calibración K")
ax.set_xlabel("Concentración (ppm)")
ax.set_ylabel("Intensidad (units arb.)")
ax.text(11000,25e4, r"$r^2 = "+str("{0:.3f}".format(r2K))+r"$", fontsize=12, color="black")
plt.show()
fig.savefig("3.pdf",bbox_inches='tight')

# %%
import sklearn.metrics as skm
from sklearn import linear_model
xMg=D1Mg[['[ppm]']] 
yMg=D1Mg[['Int']]
reg = linear_model.LinearRegression()
reg.fit(xMg, yMg)
y4_pred = reg.predict(xMg)
mMg=reg.coef_[0]
bMg=reg.intercept_[0]
mse=skm.mean_squared_error(yMg, y4_pred)
r2Mg=skm.r2_score(yMg, y4_pred)
xMg= np.array(xMg)

# %%
fig, ax= plt.subplots()
ax.scatter(xMg, yMg, color='green', label='Datos originales', edgecolors='black')
ax.plot(xMg, y4_pred, 'r', label='Ajuste')
ax.legend()
ax.set_title("Curva de Calibración Mg")
ax.set_xlabel("Concentración (ppm)")
ax.set_ylabel("Intensidad (units arb.)")
ax.text(11000,10e4, r"$r^2 = "+str("{0:.3f}".format(r2Mg))+r"$", fontsize=12, color="black")
plt.show()
fig.savefig("4.pdf",bbox_inches='tight')

# %% [markdown]
# ### <font color=red> Matriz 2x2 de las Curvas de Calibración.

# %%
fig, ax= plt.subplots(2,2, figsize=(20, 12))
ax[0,0].scatter(x, y, color='green', label='Datos originales', edgecolors='black')
ax[0,0].plot(x, y1_pred, 'r', label='Ajuste')
ax[0,0].legend()
ax[0,0].set_title("Curva de Calibración Na")
ax[0,0].set_xlabel("Concentración (ppm)")
ax[0,0].set_ylabel("Intensidad (units arb.)")
ax[0,0].text(30000,0.4e6, r"$r^2 = "+str("{0:.3f}".format(r2))+r"$", fontsize=12, color="black")

ax[0,1].scatter(xCa, yCa, color='green', label='Datos originales', edgecolors='black')
ax[0,1].plot(xCa, y2_pred, 'r', label='Ajuste')
ax[0,1].legend()
ax[0,1].set_title("Curva de Calibración Ca")
ax[0,1].set_xlabel("Concentración (ppm)")
ax[0,1].set_ylabel("Intensidad (units arb.)")
ax[0,1].text(14000,15e4, r"$r^2 = "+str("{0:.3f}".format(r2Ca))+r"$", fontsize=12, color="black")

ax[1,0].scatter(xK, yK, color='green', label='Datos originales', edgecolors='black')
ax[1,0].plot(xK, y3_pred, 'r', label='Ajuste')
ax[1,0].legend()
ax[1,0].set_title("Curva de Calibración K")
ax[1,0].set_xlabel("Concentración (ppm)")
ax[1,0].set_ylabel("Intensidad (units arb.)")
ax[1,0].text(10000,22e4, r"$r^2 = "+str("{0:.3f}".format(r2K))+r"$", fontsize=12, color="black")

ax[1,1].scatter(xMg, yMg, color='green', label='Datos originales', edgecolors='black')
ax[1,1].plot(xMg, y4_pred, 'r', label='Ajuste')
ax[1,1].legend()
ax[1,1].set_title("Curva de Calibración Mg")
ax[1,1].set_xlabel("Concentración (ppm)")
ax[1,1].set_ylabel("Intensidad (units arb.)")
ax[1,1].text(11000, 9e4, r"$r^2 = "+str("{0:.3f}".format(r2Mg))+r"$", fontsize=12, color="black")

plt.show()
fig.savefig("asdf.pdf",bbox_inches='tight')

# %% [markdown]
# ## <font color=red> Determinación de las concentraciones utilizando una muestra desconocida.

# %% [markdown]
# #### <font color=purple> Muestra desconocida del Na.

# %%
descoNa=pd.read_csv("C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main./Datos/Na/MUESTRA DESCONOCIDA/muestra desxx v2.asc", header=None, delimiter='\t')
fig, esp= plt.subplots(figsize=(12, 6))
esp.set_xlim(568, 612)
esp.set_title("LIBS muestra desc 1 espectro Na")
esp.set_xlabel("Wavelenght (nm)")
esp.set_ylabel("Intensity (arb. units)");
esp.plot(descoNa[0],descoNa[1])

# %%
plt.plot(descoNa[480:510]-np.min(ysNa[0:,0]));

# %%
AdescNa=(descoNa[480:510]-np.min(ysNa[0:,0])).sum(axis=0)
AdescNa=pd.DataFrame(AdescNa)
print(AdescNa)
# Out:
#               0
# 0 -1.245949e+06
# 1  4.907450e+05

# %%
XNa=((AdescNa-b)/m)
Na_1=np.array(15144.220609)
Na_2=np.array(4.907450e+05)
print(XNa)
# Out:
#               0
# 0 -96799.307795
# 1  15144.220609

# %% [markdown]
# #### <font color=purple> Muestra desconocida del Ca.

# %%
descoCa=pd.read_csv("C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/Ca/desconocidad 2/muestra zz v4.asc", header=None, delimiter='\t')
fig, esp= plt.subplots(figsize=(12, 6))
esp.set_xlim(378, 422)
esp.set_title("LIBS muestra desc 2 espectro Ca")
esp.set_xlabel("Wavelenght (nm)")
esp.set_ylabel("Intensity (arb. units)");
esp.plot(descoCa[0],descoCa[1])

# %%
plt.plot(descoCa[330:400]-np.min(ysCa[0:,0]));

# %%
AdescCa=(descoCa[330:400]-np.min(ysCa[0:,0])).sum(axis=0)
AdescCa=pd.DataFrame(AdescCa)
print(AdescCa)
# Out:
#               0
# 0 -2.915380e+06
# 1  1.494680e+05

# %%
XCa=((AdescCa-bCa)/mCa)
Ca_1=np.array(5047.156902)
Ca_2=np.array(1.494680e+05)
print(XCa)
# Out:
#                0
# 0 -186633.596075
# 1    5047.156902

# %% [markdown]
# #### <font color=purple> Muestra desconocida del K.

# %%
descoK=pd.read_csv("C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main/Datos/K/muestra desc 1/muestra xx v2.asc", header=None, delimiter='\t')
fig, esp= plt.subplots(figsize=(12, 6))
esp.set_xlim(739, 781)
esp.set_title("LIBS muestra desc 1 espectro K")
esp.set_xlabel("Wavelenght (nm)")
esp.set_ylabel("Intensity (arb. units)");
esp.plot(descoK[0],descoK[1])

# %%
plt.plot(descoK[170:210]-np.min(ysK[0:,0]));

# %%
AdescK=(descoK[170:210]-np.min(ysK[0:,0])).sum(axis=0)
AdescK=pd.DataFrame(AdescK)
print(AdescK)
# Out:
#               0
# 0 -1.647496e+06
# 1  3.709810e+05

# %%
XK=((AdescK-bK)/mK)
K_1=np.array(13395.207841)
K_2=np.array(3.709810e+05)
print(XK)
# Out:
#                0
# 0 -132382.744313
# 1   13395.207841

# %% [markdown]
# #### <font color=purple> Muestra desconocida del Mg.

# %%
descoMg=pd.read_csv("C://Users/laura/OneDrive/Escritorio/Analisis/Analisis_Datos_Quimica-main./Datos/Mg/desco 1/desco 1 v2.asc", header=None, delimiter='\t')
fig, esp= plt.subplots(figsize=(12, 6))
esp.set_xlim(258, 302)
esp.set_title("LIBS muestra desc 1 espectro Mg")
esp.set_xlabel("Wavelenght (nm)")
esp.set_ylabel("Intensity (arb. units)");
esp.plot(descoMg[0],descoMg[1])

# %%
plt.plot(descoMg[480:510]-np.min(ysMg[0:,0]));

# %%
AdescMg=(descoMg[480:510]-np.min(ysMg[0:,0])).sum(axis=0)
AdescMg=pd.DataFrame(AdescMg)
print(AdescMg)
# Out:
#               0
# 0 -1.246309e+06
# 1  1.565460e+05

# %%
XMg=((AdescMg-bMg)/mMg)
Mg_1=np.array(12561.538105)
Mg_2=np.array(1.565460e+05)
print(XMg)
# Out:
#                0
# 0 -158339.973098
# 1   12561.538105

# %%
fig, ax= plt.subplots(2,2, figsize=(20, 12))
ax[0,0].scatter(x, y, color='green', label='Datos originales', edgecolors='black')
ax[0,0].plot(x, y1_pred, 'r', label='Ajuste')
ax[0,0].plot(Na_1, Na_2, color='orange', label='Concentración desc Na', marker='s')
ax[0,0].legend()
ax[0,0].set_title("Curva de Calibración Na")
ax[0,0].set_xlabel("Concentración (ppm)")
ax[0,0].set_ylabel("Intensidad (units arb.)")
ax[0,0].text(30000,0.4e6, r"$r^2 = "+str("{0:.3f}".format(r2))+r"$", fontsize=12, color="black")

ax[0,1].scatter(xCa, yCa, color='green', label='Datos originales', edgecolors='black')
ax[0,1].plot(xCa, y2_pred, 'r', label='Ajuste')
ax[0,1].plot(Ca_1, Ca_2, color='orange', label='Concentración desc Ca', marker='s')
ax[0,1].legend()
ax[0,1].set_title("Curva de Calibración Ca")
ax[0,1].set_xlabel("Concentración (ppm)")
ax[0,1].set_ylabel("Intensidad (units arb.)")
ax[0,1].text(14000,15e4, r"$r^2 = "+str("{0:.3f}".format(r2Ca))+r"$", fontsize=12, color="black")

ax[1,0].scatter(xK, yK, color='green', label='Datos originales', edgecolors='black')
ax[1,0].plot(xK, y3_pred, 'r', label='Ajuste')
ax[1,0].plot(K_1, K_2, color='orange', label='Concentración desc K', marker='s')
ax[1,0].legend()
ax[1,0].set_title("Curva de Calibración K")
ax[1,0].set_xlabel("Concentración (ppm)")
ax[1,0].set_ylabel("Intensidad (units arb.)")
ax[1,0].text(10000,22e4, r"$r^2 = "+str("{0:.3f}".format(r2K))+r"$", fontsize=12, color="black")

ax[1,1].scatter(xMg, yMg, color='green', label='Datos originales', edgecolors='black')
ax[1,1].plot(xMg, y4_pred, 'r', label='Ajuste')
ax[1,1].plot(Mg_1, Mg_2, color='orange', label='Concentración desc Mg', marker='s')
ax[1,1].legend()
ax[1,1].set_title("Curva de Calibración Mg")
ax[1,1].set_xlabel("Concentración (ppm)")
ax[1,1].set_ylabel("Intensidad (units arb.)")
ax[1,1].text(11000, 9e4, r"$r^2 = "+str("{0:.3f}".format(r2Mg))+r"$", fontsize=12, color="black")

plt.show()
fig.savefig("1234.pdf",bbox_inches='tight')
